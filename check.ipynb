# %%
import torch
import os
import numpy as np
import librosa
from tqdm import tqdm
import soundfile as sf
import torchaudio
from IPython.display import Audio
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
check_file = "/home/v-yuancwang/AudioEditing/metadata_infos/replacement_refine.txt"
with open(check_file, "r") as f:
    lines = f.readlines()
for line in tqdm(lines[:]):
    src, tgt, text = line.replace("\n", "").split("   ")
    src_mel = np.load(src)
    contain_nan = (True in np.isnan(src_mel))
    if contain_nan:
        print(src)
    tgt_mel = np.load(tgt)
    contain_nan = (True in np.isnan(tgt_mel))
    if contain_nan:
        print(tgt)
    # print(src_mel.max(), src_mel.min())
    # print(tgt_mel.max(), tgt_mel.min())
    # print(text)
# Out:
# 100%|██████████| 50000/50000 [02:03<00:00, 405.24it/s]

# %%
plt.imshow(src_mel)

# %%
plt.imshow(tgt_mel)

# %%
bad_mel = np.load("/blob/v-yuancwang/audio_editing_data/add_refine/mel/audiosetfsdescgen46595.npy")
plt.imshow(bad_mel)
# print(bad_mel)
# Out:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
